# %%
import structuralanalysistoolbox as stbox

# %%
model = stbox.Model("MyModel")
model.import_mesh(r"C:\Users\yigit\StructuralAnalysisToolbox\examples\Damper.cdb")

# %%
model.mesh.get_mapdl_types()
# Out:
# [Solid185(
#    name = '',
#    name = '',
#    midx = np.int32(1),
#    technology = <Tech185.full_integration: 0>,
#    formulation = <Form185.pure_displacement: 0>,
#    layering = <Layer.non_layered: 0>,
#    pml_absorbing = <PML.not_include: 0>,
#    steady_state = <Steady.disabled: 0>,
#    extra_surface_output = <SurfOut.basic: 0>,
#  ),
# ...

# %%
model.mesh.get_pyvista_types()
# Out:
# ['TETRA', 'HEXAHEDRON', 'WEDGE']

# %%
model.plot_mesh()
# Out:
# Widget(value='<iframe src="http://localhost:65066/index.html?ui=P_0x1b4436157f0_0&reconnect=auto" class="pyvis…
