# %% [markdown]
# Import stbox Library

# %%
import structuralanalysistoolbox as stbox

# %% [markdown]
# Create Model Object

# %%
model = stbox.Model(name="my-model")

# %% [markdown]
# Import Mesh into the 'model'

# %%
model.import_mesh(r'C:\Users\yigit\StructuralAnalysisToolbox\examples\meshes\cantilevier_beam.cdb')
model.plot_mesh()
# Out:
# Widget(value='<iframe src="http://localhost:63944/index.html?ui=P_0x2736c4e5be0_0&reconnect=auto" class="pyvis…

# %% [markdown]
# Select and Assign Material

# %%
# List Predefined Materials
stbox.matlib.list_materials()
# Out:
# My Steel
# My Steel-2
# My Steel-3
# My Steel-4
# Linear Steel

# %%
# Select and Assign Material
steel = model.add_material(mat="Linear Steel")
model.assign_material("MESH", steel)

# %% [markdown]
# Create Load Steps

# %%
load_step_1 = model.add_loadstep(name="Pressure_Load_1")

# %% [markdown]
# Apply Boundary Conditions

# %%
# Apply Pressure Through Node Set (SF)
load_step_1.pressure(nset="LOADING_NODES",
                     value= 10.0,
                     applied_by="NODE SET",
                     operation="NEW")

# Apply dof constraints
load_step_1.dof("NS_FIX", "ALL", 0)

# %% [markdown]
# Specify Load Step Outputs

# %%
load_step_1.output("NODAL DOF", "ALL")
load_step_1.output("REACTION LOADS", "ALL")
load_step_1.output("NODAL-AVG PLASTIC STRAINS", "ALL")
load_step_1.output("NODAL-AVG STRESSES", "ALL")
load_step_1.output("EL-NODAL LOAD", "ALL")

# %% [markdown]
# Check Model Configuration

# %%
model.info()
# Out:
#  ├── Element Types
#  │   └── SOLID185
#  ├── Materials
#  │   └── Linear Steel
#  ├── Sets
#  │   ├── Node Sets
#  │   │   ├── LOADING_NODES
#  │   │   ├── LOADING_NODES_2
#  │   │   ├── NS_FIX
#  │   │   ├── _CM35PRES
#  │   │   └── _FIXEDSU
#  │   └── Element Sets
#  │       └── MESH
#  ├── Surfaces
#  │   └── Surf_Pres_LOADING_NODES
#  ├── Local Coordinate Systems
#  ├── Sections
#  ├── Constraints
#  │   ├── Linear Couplings
#  │   ├── Constraint Equations
#  │   ├── MPC
#  │   └── Joints
#  ├── Contacts
#  └── Load Steps
#      └── Pressure_Load_1

# %% [markdown]
# Solve Model

# %%
model.solve()
#model.write_input_file()

# %% [markdown]
# Retrieve Result

# %%
result = model.solution()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\yigit\StructuralAnalysisToolbox\.venv\Lib\site-packages\ansys\dpf\core\cyberchannel.py:349, in create_mtls_channel(host, port, certs_dir, cert_files, grpc_options)
#     348 try:
# --> 349     with (ca_file).open("rb") as f:
#     350         trusted_certs = f.read()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\pathlib\_local.py:537, in Path.open(self, mode, buffering, encoding, errors, newline)
#     536     encoding = io.text_encoding(encoding)
# --> 537 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'certs\\ca.crt'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 result = model.solution()
#
# File ~\StructuralAnalysisToolbox\src\structuralanalysistoolbox\model.py:661, in Model.solution(self)
#     659 if self.solver_name == "MAPDL":
#     660     from structuralanalysistoolbox.post.mapdl import solutions
# --> 661     solution = solutions.DpfSolution(_result_file_path)
#     663 return solution.simulation
#
# File ~\StructuralAnalysisToolbox\src\structuralanalysistoolbox\post\mapdl\solutions.py:9, in DpfSolution.__init__(self, file_path)
#       6 def __init__(self, file_path: Path):
#       7     """Initialize DpfSolution object."""
# ----> 9     self._simulation = post.load_simulation(file_path)
#
# File c:\Users\yigit\StructuralAnalysisToolbox\.venv\Lib\site-packages\ansys\dpf\post\post_utility.py:188, in load_simulation(data_sources, simulation_type, server)
#     140 def load_simulation(
#     141     data_sources,
#     142     simulation_type: Union[AvailableSimulationTypes, str] = None,
#     143     server: Union[BaseServer, None] = None,
#     144 ) -> SimulationType:
#     145     """Loads a simulation and returns a :class:`ansys.dpf.post.simulation.Simulation` object.
#     146
#     147     This class provides the main interface to explore and manipulate results, meshes, geometries,
#    (...)    186     >>> simulation = post.load_simulation(examples.static_rst)
#     187     """
# --> 188     _model = Model(data_sources, server=server)
#     189     data_sources = _model.metadata.data_sources
#     191     if not simulation_type:
#
# File c:\Users\yigit\StructuralAnalysisToolbox\.venv\Lib\site-packages\ansys\dpf\core\model.py:74, in Model.__init__(self, data_sources, server)
#      72 """Initialize connection with DPF server."""
#      73 if server is None:
# ---> 74     server = dpf.core._global_server()
#      76 self._data_sources = data_sources
#      77 self._server = server
#
# File c:\Users\yigit\StructuralAnalysisToolbox\.venv\Lib\site-packages\ansys\dpf\core\server.py:110, in _global_server()
#     107             connect_to_server(ip, port)
#     108         # if true, start a server
#     109         else:
# --> 110             start_local_server(as_global=True)
#     111     return dpf.core.SERVER
#     112 return None
#
# File c:\Users\yigit\StructuralAnalysisToolbox\.venv\Lib\site-packages\ansys\dpf\core\server.py:287, in start_local_server(ip, port, ansys_path, as_global, load_operators, use_docker_by_default, docker_config, timeout, config, use_pypim_by_default, context)
#     285     else:
#     286         config = ServerConfig()
# --> 287     server = server_type(
#     288         ansys_path,
#     289         ip,
#     290         port,
#     291         as_global=as_global,
#     292         launch_server=True,
#     293         load_operators=load_operators,
#     294         docker_config=docker_config,
#     295         timeout=timeout,
#     296         use_pypim=use_pypim,
#     297         context=context,
#     298         grpc_mode=grpc_mode,
#     299         certificates_dir=certs_dir,
#     300     )
#     301 else:
#     302     server = server_type(
#     303         ansys_path,
#     304         as_global=as_global,
#    (...)    307         context=context,
#     308     )
#
# File c:\Users\yigit\StructuralAnalysisToolbox\.venv\Lib\site-packages\ansys\dpf\core\server_types.py:1406, in LegacyGrpcServer.__init__(self, ansys_path, ip, port, timeout, as_global, load_operators, launch_server, docker_config, use_pypim, context, grpc_mode, certificates_dir)
#    1402     self.channel = cyberchannel.create_channel(
#    1403         transport_mode="insecure", host=ip, port=port
#    1404     )
#    1405 elif self._grpc_mode == server_factory.GrpcMode.mTLS:
# -> 1406     self.channel = cyberchannel.create_channel(
#    1407         transport_mode="mtls", host=ip, port=port, certs_dir=self._certs_dir
#    1408     )
#    1410 # store the address for later reference
#    1411 self._address = address
#
# File c:\Users\yigit\StructuralAnalysisToolbox\.venv\Lib\site-packages\ansys\dpf\core\cyberchannel.py:147, in create_channel(transport_mode, host, port, uds_service, uds_dir, uds_id, certs_dir, cert_files, grpc_options)
#     145 case "mtls":
#     146     transport_mode, host, port = check_host_port(transport_mode, host, port)
# --> 147     return create_mtls_channel(host, port, certs_dir, cert_files, grpc_options)
#     148 case _:
#     149     raise ValueError(
#     150         f"Unknown transport mode: {transport_mode}. "
#     151         "Valid options are: 'insecure', 'uds', 'wnua', 'mtls'."
#     152     )
#
# File c:\Users\yigit\StructuralAnalysisToolbox\.venv\Lib\site-packages\ansys\dpf\core\cyberchannel.py:362, in create_mtls_channel(host, port, certs_dir, cert_files, grpc_options)
#     357     if certs_folder is not None:
#     358         error_message += (
#     359             f"Ensure that the certificates are present in the '{certs_folder}' folder or "
#     360             "set the 'ANSYS_GRPC_CERTIFICATES' environment variable."
#     361         )
# --> 362     raise FileNotFoundError(error_message) from e
#     364 # Create SSL credentials
#     365 credentials = grpc.ssl_channel_credentials(
#     366     root_certificates=trusted_certs, private_key=client_key, certificate_chain=client_cert
#     367 )
#
# FileNotFoundError: Certificate file not found: certs\ca.crt. Ensure that the certificates are present in the 'certs' folder or set the 'ANSYS_GRPC_CERTIFICATES' environment variable.

# %%
# Displacement Result
von_misses = result.stress_eqv_von_mises_nodal()
von_misses.animate(deform=True, factor=10.0)
# Out:
# Orient the view, then press "a" to produce an animation
# Widget(value='<iframe src="http://localhost:63149/index.html?ui=P_0x197e4a40190_1&reconnect=auto" class="pyvis…
