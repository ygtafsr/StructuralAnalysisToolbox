# %%
import structuralanalysistoolbox as stbox

# %% [markdown]
# ### Create Model Object

# %%
model = stbox.Model(name="my-model")

# %% [markdown]
# ### Import Mesh

# %%
model.import_mesh(r'C:\Users\yigit\StructuralAnalysisToolbox\examples\meshes\cantilevier_beam.cdb')
model.plot_mesh()
# Out:
# Widget(value='<iframe src="http://localhost:58498/index.html?ui=P_0x25caeaf5fd0_0&reconnect=auto" class="pyvis…
# Exception raised
# AttributeError("'NoneType' object has no attribute 'interactor'")
# Traceback (most recent call last):
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\wslink\protocol.py", line 324, in onCompleteMessage
#     results = func(*args, **kwargs)
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_server\protocol.py", line 226, in update_state
#     with self.server.state:
#          ^^^^^^^^^^^^^^^^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_server\state.py", line 333, in __exit__
#     self.flush()
#     ~~~~~~~~~~^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_server\state.py", line 311, in flush
#     coroutine = callback(**self._pushed_state)
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvista\trame\ui\base_viewer.py", line 230, in on_axis_visibility_change
#     renderer.show_axes()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvista\plotting\renderer.py", line 1575, in show_axes
#     self.add_axes()
#     ~~~~~~~~~~~~~^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvista\plotting\renderer.py", line 1313, in add_axes
#     axes_widget = self.add_orientation_widget(
#         self.axes_actor,
#         interactive=interactive,
#         color=None,
#     )
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvista\plotting\renderer.py", line 1157, in add_orientation_widget
#     self.axes_widget.SetInteractor(self.parent.iren.interactor)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'interactor'
#
# Exception raised
# AttributeError("'NoneType' object has no attribute 'GetRenderWindow'")
# Traceback (most recent call last):
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\wslink\protocol.py", line 324, in onCompleteMessage
#     results = func(*args, **kwargs)
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_server\protocol.py", line 226, in update_state
#     with self.server.state:
#          ^^^^^^^^^^^^^^^^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_server\state.py", line 333, in __exit__
#     self.flush()
#     ~~~~~~~~~~^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_server\state.py", line 311, in flush
#     coroutine = callback(**self._pushed_state)
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvista\trame\ui\base_viewer.py", line 236, in on_axis_visibility_change
#     view.set_widgets(
#     ~~~~~~~~~~~~~~~~^
#         [
#         ^
#     ...<3 lines>...
#         ],
#         ^^
#     )
#     ^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_vtk\widgets\vtk\common.py", line 649, in set_widgets
#     self.update_geometry()
#     ~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_vtk\widgets\vtk\common.py", line 506, in update_geometry
#     delta_state = self._helper.scene(
#         self.__view,
#     ...<2 lines>...
#         orientation_axis=orientation_axis,
#     )
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_vtk\modules\vtk\__init__.py", line 78, in scene
#     scene_state = self._trame_server.protocol_call(
#         "viewport.geometry.view.get.state",
#     ...<3 lines>...
#         orientation_axis=orientation_axis,
#     )
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_server\core.py", line 515, in protocol_call
#     return func(obj, *args, **kwargs)
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py", line 129, in get_view_state
#     serialize_widget(behaviors, widget)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_vtk\modules\vtk\serializers\serialize.py", line 30, in serialize_widget
#     handle_widget(dict_out, widget)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_vtk\modules\vtk\serializers\widgets.py", line 50, in handle_widget
#     SERIALIZERS[class_name](map_to_update, widget)
#     ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_vtk\modules\vtk\serializers\widgets.py", line 20, in orientation_marker_widget
#     rw = widget.GetInteractor().GetRenderWindow()
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'GetRenderWindow'

# %% [markdown]
# ### Select and Assign Material

# %%
stbox.matlib.list_materials()
# Out:
# My Steel
# My Steel-2
# My Steel-3
# My Steel-4
# Linear Steel

# %%
steel = model.add_material(mat="Linear Steel")
model.assign_material("MESH", steel)

# %% [markdown]
# ### Create Load Steps

# %%
load_step_1 = model.add_loadstep(name="Pressure_Load_1")

# %% [markdown]
# Apply Pressure Through Surface Elements (SURF154+SF)

# %%
load_step_1.pressure(nset="LOADING_NODES",
                     value=20,
                     direction='X',
                     applied_by="SURFACE ELEMENTS")
load_step_1.dof("NS_FIX", "ALL", 0)

load_step_1.output("NODAL DOF", "ALL")
load_step_1.output("REACTION LOADS", "ALL")
load_step_1.output("NODAL-AVG PLASTIC STRAINS", "ALL")
load_step_1.output("NODAL-AVG STRESSES", "ALL")
load_step_1.output("EL-NODAL LOAD", "ALL")

# %%
model.info()
# Out:
#  ├── Element Types
#  │   ├── SOLID185
#  │   └── SURF154
#  ├── Materials
#  │   └── Linear Steel
#  ├── Sets
#  │   ├── Node Sets
#  │   │   ├── LOADING_NODES
#  │   │   ├── LOADING_NODES_2
#  │   │   ├── NS_FIX
#  │   │   ├── _CM35PRES
#  │   │   └── _FIXEDSU
#  │   └── Element Sets
#  │       └── MESH
#  ├── Surfaces
#  │   └── Surf_Pres_LOADING_NODES
#  ├── Local Coordinate Systems
#  │   └── CSYS-11
#  ├── Sections
#  ├── Constraints
#  │   ├── Linear Couplings
#  │   ├── Constraint Equations
#  │   ├── MPC
#  │   └── Joints
#  ├── Contacts
#  └── Load Steps
#      └── Pressure_Load_1

# %%
model.solve()
#model.write_input_file()

# %%
from ansys.dpf import post
simulation = post.load_simulation(r"C:\Users\yigit\StructuralAnalysisToolbox\examples\06_Solution\my-model-21.01.2026-11.34.10\my-model.rst")
# Out:
# c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\ansys\dpf\core\misc.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
mesh = simulation.mesh
print(mesh)

# %%
displacement_norm = simulation.displacement(norm=True)
displacement_norm.animate(deform=True, factor=1.0)
# Out:
# Orient the view, then press "a" to produce an animation
# Widget(value='<iframe src="http://localhost:58668/index.html?ui=P_0x24140da96a0_0&reconnect=auto" class="pyvis…
# Exception raised
# AttributeError("'NoneType' object has no attribute 'interactor'")
# Traceback (most recent call last):
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\wslink\protocol.py", line 324, in onCompleteMessage
#     results = func(*args, **kwargs)
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_server\protocol.py", line 226, in update_state
#     with self.server.state:
#          ^^^^^^^^^^^^^^^^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_server\state.py", line 333, in __exit__
#     self.flush()
#     ~~~~~~~~~~^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\trame_server\state.py", line 311, in flush
#     coroutine = callback(**self._pushed_state)
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvista\trame\ui\base_viewer.py", line 230, in on_axis_visibility_change
#     renderer.show_axes()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvista\plotting\renderer.py", line 1575, in show_axes
#     self.add_axes()
#     ~~~~~~~~~~~~~^^
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvista\plotting\renderer.py", line 1313, in add_axes
#     axes_widget = self.add_orientation_widget(
#         self.axes_actor,
#         interactive=interactive,
#         color=None,
#     )
#   File "c:\Users\yigit\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyvista\plotting\renderer.py", line 1157, in add_orientation_widget
#     self.axes_widget.SetInteractor(self.parent.iren.interactor)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'interactor'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
von_misses = simulation.stress_eqv_von_mises_nodal()
von_misses.animate(deform=True, factor=10.0)
